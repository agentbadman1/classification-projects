# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Telecom_customer_churn.csv')

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.shape
# Out:
# (7043, 21)

# %%
data.set_index('customerID',inplace=True)

# %%
data.head()
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No       1           No
# 5575-GNVDE    Male              0      No         No      34          Yes
# 3668-QPYBK    Male              0      No         No       2          Yes
# 7795-CFOCW    Male              0      No         No      45           No
# 9237-HQITU  Female              0      No         No       2          Yes
#
#                MultipleLines InternetService OnlineSecurity OnlineBackup  \
# customerID
# 7590-VHVEG  No phone service             DSL             No          Yes
# 5575-GNVDE                No             DSL            Yes           No
# 3668-QPYBK                No             DSL            Yes          Yes
# 7795-CFOCW  No phone service             DSL            Yes           No
# 9237-HQITU                No     Fiber optic             No           No
#
# ...

# %%
data.shape
# Out:
# (7043, 20)

# %%
data.isna().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (7021, 20)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7021 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7021 non-null   object
#  1   SeniorCitizen     7021 non-null   int64
#  2   Partner           7021 non-null   object
#  3   Dependents        7021 non-null   object
#  4   tenure            7021 non-null   int64
#  5   PhoneService      7021 non-null   object
#  6   MultipleLines     7021 non-null   object
#  7   InternetService   7021 non-null   object
#  8   OnlineSecurity    7021 non-null   object
#  9   OnlineBackup      7021 non-null   object
#  10  DeviceProtection  7021 non-null   object
#  11  TechSupport       7021 non-null   object
#  12  StreamingTV       7021 non-null   object
#  13  StreamingMovies   7021 non-null   object
#  14  Contract          7021 non-null   object
#  15  PaperlessBilling  7021 non-null   object
# ...

# %%
data[data['TotalCharges']==' ']
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 4472-LVYGI  Female              0     Yes        Yes       0           No
# 3115-CZMZD    Male              0      No        Yes       0          Yes
# 5709-LVOEQ  Female              0     Yes        Yes       0          Yes
# 4367-NUYAO    Male              0     Yes        Yes       0          Yes
# 1371-DWPAZ  Female              0     Yes        Yes       0           No
# 7644-OMVMY    Male              0     Yes        Yes       0          Yes
# 3213-VVOLG    Male              0     Yes        Yes       0          Yes
# 2520-SGTTA  Female              0     Yes        Yes       0          Yes
# 2923-ARZLG    Male              0     Yes        Yes       0          Yes
# 4075-WKNIU  Female              0     Yes        Yes       0          Yes
# 2775-SEFEE    Male              0      No        Yes       0          Yes
#
# ...

# %%
data['TotalCharges'].replace(' ',np.nan,inplace=True)

# %%
data.isna().sum()
# Out:
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (7010, 20)

# %%
data['TotalCharges'] = data['TotalCharges'].astype('float64')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7010 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7010 non-null   object
#  1   SeniorCitizen     7010 non-null   int64
#  2   Partner           7010 non-null   object
#  3   Dependents        7010 non-null   object
#  4   tenure            7010 non-null   int64
#  5   PhoneService      7010 non-null   object
#  6   MultipleLines     7010 non-null   object
#  7   InternetService   7010 non-null   object
#  8   OnlineSecurity    7010 non-null   object
#  9   OnlineBackup      7010 non-null   object
#  10  DeviceProtection  7010 non-null   object
#  11  TechSupport       7010 non-null   object
#  12  StreamingTV       7010 non-null   object
#  13  StreamingMovies   7010 non-null   object
#  14  Contract          7010 non-null   object
#  15  PaperlessBilling  7010 non-null   object
# ...

# %%
data.head()
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No       1           No
# 5575-GNVDE    Male              0      No         No      34          Yes
# 3668-QPYBK    Male              0      No         No       2          Yes
# 7795-CFOCW    Male              0      No         No      45           No
# 9237-HQITU  Female              0      No         No       2          Yes
#
#                MultipleLines InternetService OnlineSecurity OnlineBackup  \
# customerID
# 7590-VHVEG  No phone service             DSL             No          Yes
# 5575-GNVDE                No             DSL            Yes           No
# 3668-QPYBK                No             DSL            Yes          Yes
# 7795-CFOCW  No phone service             DSL            Yes           No
# 9237-HQITU                No     Fiber optic             No           No
#
# ...

# %%
cat_data = data.select_dtypes('object').columns.tolist()

# %%
cont_data = data.select_dtypes(['int64','float64']).columns.tolist()

# %%
cat_data
# Out:
# ['gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'Churn']

# %%
cont_data
# Out:
# ['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges']

# %%
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder

# %%
le = LabelEncoder()
oe = OrdinalEncoder()

# %%
print(f"unique values are {data['gender'].nunique()}")

data['gender'].value_counts()
# Out:
# unique values are 2
# Male      3535
# Female    3475
# Name: gender, dtype: int64

# %%
data['gender'] = le.fit_transform(data['gender'])

# %%
data.head()
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG       0              0     Yes         No       1           No
# 5575-GNVDE       1              0      No         No      34          Yes
# 3668-QPYBK       1              0      No         No       2          Yes
# 7795-CFOCW       1              0      No         No      45           No
# 9237-HQITU       0              0      No         No       2          Yes
#
#                MultipleLines InternetService OnlineSecurity OnlineBackup  \
# customerID
# 7590-VHVEG  No phone service             DSL             No          Yes
# 5575-GNVDE                No             DSL            Yes           No
# 3668-QPYBK                No             DSL            Yes          Yes
# 7795-CFOCW  No phone service             DSL            Yes           No
# 9237-HQITU                No     Fiber optic             No           No
#
# ...

# %%
print(f"unique values are {data['Partner'].nunique()}")

data['Partner'].value_counts()
# Out:
# unique values are 2
# No     3617
# Yes    3393
# Name: Partner, dtype: int64

# %%
data['Partner'] = le.fit_transform(data['Partner'])

# %%
data.head()
# Out:
#             gender  SeniorCitizen  Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG       0              0        1         No       1           No
# 5575-GNVDE       1              0        0         No      34          Yes
# 3668-QPYBK       1              0        0         No       2          Yes
# 7795-CFOCW       1              0        0         No      45           No
# 9237-HQITU       0              0        0         No       2          Yes
#
#                MultipleLines InternetService OnlineSecurity OnlineBackup  \
# customerID
# 7590-VHVEG  No phone service             DSL             No          Yes
# 5575-GNVDE                No             DSL            Yes           No
# 3668-QPYBK                No             DSL            Yes          Yes
# 7795-CFOCW  No phone service             DSL            Yes           No
# 9237-HQITU                No     Fiber optic             No           No
#
# ...

# %%
print(f"unique values are {data['Dependents'].nunique()}")

data['Dependents'].value_counts()
# Out:
# unique values are 2
# No     4911
# Yes    2099
# Name: Dependents, dtype: int64

# %%
data['Dependents'] = le.fit_transform(data['Dependents'])

# %%
data.head()
# Out:
#             gender  SeniorCitizen  Partner  Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG       0              0        1           0       1           No
# 5575-GNVDE       1              0        0           0      34          Yes
# 3668-QPYBK       1              0        0           0       2          Yes
# 7795-CFOCW       1              0        0           0      45           No
# 9237-HQITU       0              0        0           0       2          Yes
#
#                MultipleLines InternetService OnlineSecurity OnlineBackup  \
# customerID
# 7590-VHVEG  No phone service             DSL             No          Yes
# 5575-GNVDE                No             DSL            Yes           No
# 3668-QPYBK                No             DSL            Yes          Yes
# 7795-CFOCW  No phone service             DSL            Yes           No
# 9237-HQITU                No     Fiber optic             No           No
#
# ...

# %%
print(f"unique values are {data['PhoneService'].nunique()}")

data['PhoneService'].value_counts()
# Out:
# unique values are 2
# Yes    6330
# No      680
# Name: PhoneService, dtype: int64

# %%
data['PhoneService'] = le.fit_transform(data['PhoneService'])

# %%
data.head()
# Out:
#             gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# customerID
# 7590-VHVEG       0              0        1           0       1             0
# 5575-GNVDE       1              0        0           0      34             1
# 3668-QPYBK       1              0        0           0       2             1
# 7795-CFOCW       1              0        0           0      45             0
# 9237-HQITU       0              0        0           0       2             1
#
#                MultipleLines InternetService OnlineSecurity OnlineBackup  \
# customerID
# 7590-VHVEG  No phone service             DSL             No          Yes
# 5575-GNVDE                No             DSL            Yes           No
# 3668-QPYBK                No             DSL            Yes          Yes
# 7795-CFOCW  No phone service             DSL            Yes           No
# 9237-HQITU                No     Fiber optic             No           No
#
# ...

# %%
print(f"unique values are {data['MultipleLines'].nunique()}")

data['MultipleLines'].value_counts()
# Out:
# unique values are 3
# No                  3363
# Yes                 2967
# No phone service     680
# Name: MultipleLines, dtype: int64

# %%
oe = OrdinalEncoder(categories=[['Yes','No','No phone service']])

# %%
data['MultipleLines'] = oe.fit_transform(data['MultipleLines'].values.reshape(-1,1))

# %%
data.head()
# Out:
#             gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# customerID
# 7590-VHVEG       0              0        1           0       1             0
# 5575-GNVDE       1              0        0           0      34             1
# 3668-QPYBK       1              0        0           0       2             1
# 7795-CFOCW       1              0        0           0      45             0
# 9237-HQITU       0              0        0           0       2             1
#
#             MultipleLines InternetService OnlineSecurity OnlineBackup  \
# customerID
# 7590-VHVEG            2.0             DSL             No          Yes
# 5575-GNVDE            1.0             DSL            Yes           No
# 3668-QPYBK            1.0             DSL            Yes          Yes
# 7795-CFOCW            2.0             DSL            Yes           No
# 9237-HQITU            1.0     Fiber optic             No           No
#
# ...

# %%
print(f"unique values are {data['InternetService'].nunique()}")

data['InternetService'].value_counts()
# Out:
# unique values are 3
# Fiber optic    3090
# DSL            2414
# No             1506
# Name: InternetService, dtype: int64

# %%
oe = OrdinalEncoder(categories=[['Fiber optic','DSL','No']])

# %%
data['InternetService'] = oe.fit_transform(data['InternetService'].values.reshape(-1,1))

# %%
data.head()
# Out:
#             gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# customerID
# 7590-VHVEG       0              0        1           0       1             0
# 5575-GNVDE       1              0        0           0      34             1
# 3668-QPYBK       1              0        0           0       2             1
# 7795-CFOCW       1              0        0           0      45             0
# 9237-HQITU       0              0        0           0       2             1
#
#             MultipleLines  InternetService OnlineSecurity OnlineBackup  \
# customerID
# 7590-VHVEG            2.0              1.0             No          Yes
# 5575-GNVDE            1.0              1.0            Yes           No
# 3668-QPYBK            1.0              1.0            Yes          Yes
# 7795-CFOCW            2.0              1.0            Yes           No
# 9237-HQITU            1.0              0.0             No           No
#
# ...

# %%
print(f"unique values are {data['OnlineSecurity'].nunique()}")

data['OnlineSecurity'].value_counts()
# Out:
# unique values are 3
# No                     3489
# Yes                    2015
# No internet service    1506
# Name: OnlineSecurity, dtype: int64

# %%
oe = OrdinalEncoder(categories=[['Yes','No','No internet service']])

# %%
data['OnlineSecurity'] = oe.fit_transform(data['OnlineSecurity'].values.reshape(-1,1))

# %%
data.head()
# Out:
#             gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# customerID
# 7590-VHVEG       0              0        1           0       1             0
# 5575-GNVDE       1              0        0           0      34             1
# 3668-QPYBK       1              0        0           0       2             1
# 7795-CFOCW       1              0        0           0      45             0
# 9237-HQITU       0              0        0           0       2             1
#
#             MultipleLines  InternetService  OnlineSecurity OnlineBackup  \
# customerID
# 7590-VHVEG            2.0              1.0             1.0          Yes
# 5575-GNVDE            1.0              1.0             0.0           No
# 3668-QPYBK            1.0              1.0             0.0          Yes
# 7795-CFOCW            2.0              1.0             0.0           No
# 9237-HQITU            1.0              0.0             1.0           No
#
# ...

# %%
print(f"unique values are {data['OnlineBackup'].nunique()}")

data['OnlineBackup'].value_counts()
# Out:
# unique values are 3
# No                     3079
# Yes                    2425
# No internet service    1506
# Name: OnlineBackup, dtype: int64

# %%
oe = OrdinalEncoder(categories=[['Yes','No','No internet service']])

# %%
data['OnlineBackup'] = oe.fit_transform(data['OnlineBackup'].values.reshape(-1,1))

# %%
data.head()
# Out:
#             gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# customerID
# 7590-VHVEG       0              0        1           0       1             0
# 5575-GNVDE       1              0        0           0      34             1
# 3668-QPYBK       1              0        0           0       2             1
# 7795-CFOCW       1              0        0           0      45             0
# 9237-HQITU       0              0        0           0       2             1
#
#             MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# customerID
# 7590-VHVEG            2.0              1.0             1.0           0.0
# 5575-GNVDE            1.0              1.0             0.0           1.0
# 3668-QPYBK            1.0              1.0             0.0           0.0
# 7795-CFOCW            2.0              1.0             0.0           1.0
# 9237-HQITU            1.0              0.0             1.0           1.0
#
# ...

# %%
print(f"unique values are {data['DeviceProtection'].nunique()}")

data['DeviceProtection'].value_counts()
# Out:
# unique values are 3
# No                     3086
# Yes                    2418
# No internet service    1506
# Name: DeviceProtection, dtype: int64

# %%
data['DeviceProtection'] = oe.fit_transform(data['DeviceProtection'].values.reshape(-1,1))

# %%
print(f"unique values are {data['TechSupport'].nunique()}")

data['TechSupport'].value_counts()
# Out:
# unique values are 3
# No                     3464
# Yes                    2040
# No internet service    1506
# Name: TechSupport, dtype: int64

# %%
data['TechSupport'] = oe.fit_transform(data['TechSupport'].values.reshape(-1,1))

# %%
print(f"unique values are {data['StreamingTV'].nunique()}")

data['StreamingTV'].value_counts()
# Out:
# unique values are 3
# No                     2801
# Yes                    2703
# No internet service    1506
# Name: StreamingTV, dtype: int64

# %%
data['StreamingTV'] = oe.fit_transform(data['StreamingTV'].values.reshape(-1,1))

# %%
data.head()
# Out:
#             gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# customerID
# 7590-VHVEG       0              0        1           0       1             0
# 5575-GNVDE       1              0        0           0      34             1
# 3668-QPYBK       1              0        0           0       2             1
# 7795-CFOCW       1              0        0           0      45             0
# 9237-HQITU       0              0        0           0       2             1
#
#             MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# customerID
# 7590-VHVEG            2.0              1.0             1.0           0.0
# 5575-GNVDE            1.0              1.0             0.0           1.0
# 3668-QPYBK            1.0              1.0             0.0           0.0
# 7795-CFOCW            2.0              1.0             0.0           1.0
# 9237-HQITU            1.0              0.0             1.0           1.0
#
# ...

# %%
print(f"unique values are {data['StreamingMovies'].nunique()}")

data['StreamingMovies'].value_counts()
# Out:
# unique values are 3
# No                     2773
# Yes                    2731
# No internet service    1506
# Name: StreamingMovies, dtype: int64

# %%
data['StreamingMovies'] = oe.fit_transform(data['StreamingMovies'].values.reshape(-1,1))

# %%
print(f"unique values are {data['Contract'].nunique()}")

data['Contract'].value_counts()
# Out:
# unique values are 3
# Month-to-month    3853
# Two year          1685
# One year          1472
# Name: Contract, dtype: int64

# %%
oe = OrdinalEncoder(categories=[['Two year','One year','Month-to-month']])

# %%
data['Contract'] = oe.fit_transform(data['Contract'].values.reshape(-1,1))

# %%
data.head()
# Out:
#             gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# customerID
# 7590-VHVEG       0              0        1           0       1             0
# 5575-GNVDE       1              0        0           0      34             1
# 3668-QPYBK       1              0        0           0       2             1
# 7795-CFOCW       1              0        0           0      45             0
# 9237-HQITU       0              0        0           0       2             1
#
#             MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# customerID
# 7590-VHVEG            2.0              1.0             1.0           0.0
# 5575-GNVDE            1.0              1.0             0.0           1.0
# 3668-QPYBK            1.0              1.0             0.0           0.0
# 7795-CFOCW            2.0              1.0             0.0           1.0
# 9237-HQITU            1.0              0.0             1.0           1.0
#
# ...

# %%
print(f"unique values are {data['PaperlessBilling'].nunique()}")

data['PaperlessBilling'].value_counts()
# Out:
# unique values are 2
# Yes    4158
# No     2852
# Name: PaperlessBilling, dtype: int64

# %%
data['PaperlessBilling'] = le.fit_transform(data['PaperlessBilling'])

# %%
print(f"unique values are {data['PaymentMethod'].nunique()}")

data['PaymentMethod'].value_counts()
# Out:
# unique values are 4
# Electronic check             2359
# Mailed check                 1588
# Bank transfer (automatic)    1542
# Credit card (automatic)      1521
# Name: PaymentMethod, dtype: int64

# %%
data['PaymentMethod'] = le.fit_transform(data['PaymentMethod'])

# %%
data.head()
# Out:
#             gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# customerID
# 7590-VHVEG       0              0        1           0       1             0
# 5575-GNVDE       1              0        0           0      34             1
# 3668-QPYBK       1              0        0           0       2             1
# 7795-CFOCW       1              0        0           0      45             0
# 9237-HQITU       0              0        0           0       2             1
#
#             MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# customerID
# 7590-VHVEG            2.0              1.0             1.0           0.0
# 5575-GNVDE            1.0              1.0             0.0           1.0
# 3668-QPYBK            1.0              1.0             0.0           0.0
# 7795-CFOCW            2.0              1.0             0.0           1.0
# 9237-HQITU            1.0              0.0             1.0           1.0
#
# ...

# %%
data['Churn'] = le.fit_transform(data['Churn'])

# %%
data.head()
# Out:
#             gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# customerID
# 7590-VHVEG       0              0        1           0       1             0
# 5575-GNVDE       1              0        0           0      34             1
# 3668-QPYBK       1              0        0           0       2             1
# 7795-CFOCW       1              0        0           0      45             0
# 9237-HQITU       0              0        0           0       2             1
#
#             MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# customerID
# 7590-VHVEG            2.0              1.0             1.0           0.0
# 5575-GNVDE            1.0              1.0             0.0           1.0
# 3668-QPYBK            1.0              1.0             0.0           0.0
# 7795-CFOCW            2.0              1.0             0.0           1.0
# 9237-HQITU            1.0              0.0             1.0           1.0
#
# ...

# %%
from scipy.stats import zscore

# %%
z = zscore(data[cont_data])

# %%
data = data[(z<3).all(axis=1)]

# %%
data.shape
# Out:
# (7010, 20)

# %%
from sklearn.feature_selection import RFE

# %%
x = data.drop('Churn',axis=1)

# %%
y = data['Churn']

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
selector = RFE(estimator=rf,n_features_to_select=13)

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()

# %%
from sklearn.model_selection import train_test_split

# %%
X = ss.fit_transform(x)

# %%
x = pd.DataFrame(X,columns=x.columns)

# %%
selector = selector.fit(x, y)

# %%
a = x.columns[selector.support_]

# %%
a
# Out:
# Index(['gender', 'Partner', 'tenure', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges'],
#       dtype='object')

# %%
x = x[a]

# %%
x.shape
# Out:
# (7010, 13)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=56)

# %%
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE()

# %%
x_train,y_train = sm.fit_resample(x_train,y_train)

# %%
y_train.value_counts()
# Out:
# 0    4130
# 1    4130
# Name: Churn, dtype: int64

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
pred = rf.predict(x_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83      1023
#            1       0.55      0.58      0.56       379
#
#     accuracy                           0.76      1402
#    macro avg       0.69      0.70      0.70      1402
# weighted avg       0.76      0.76      0.76      1402

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
pred = knn.predict(x_test)

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.70      0.77      1023
#            1       0.45      0.66      0.53       379
#
#     accuracy                           0.69      1402
#    macro avg       0.65      0.68      0.65      1402
# weighted avg       0.74      0.69      0.70      1402
